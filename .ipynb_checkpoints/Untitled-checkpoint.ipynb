# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
rhos = pd.read_csv('therm/total_s10by10.dat', header=None, skiprows=1).to_numpy()
print(str(np.shape(rhos)[0]) + " runs, each of " + str(np.shape(rhos)[1]-1) + " steps")
rho_bar = np.average(rhos, axis=0)
plt.plot(rho_bar)
rhos = pd.read_csv('therm/total_s10by101.dat', header=None, skiprows=1).to_numpy()
print(str(np.shape(rhos)[0]) + " runs, each of " + str(np.shape(rhos)[1]-1) + " steps")
rho_bar = np.average(rhos, axis=0)
plt.plot(rho_bar)
rhos = pd.read_csv('therm/total_s10by102.dat', header=None, skiprows=1).to_numpy()
print(str(np.shape(rhos)[0]) + " runs, each of " + str(np.shape(rhos)[1]-1) + " steps")
rho_bar = np.average(rhos, axis=0)
plt.plot(rho_bar)

plt.ylim([190,210])
plt.show()
# Out:
# 2000 runs, each of 200 steps
# 2000 runs, each of 200 steps
# 2000 runs, each of 200 steps

# %%
rhos = pd.read_csv('therm/total_s10by10longer.dat', header=None, skiprows=1).to_numpy()
print(str(np.shape(rhos)[0]) + " runs, each of " + str(np.shape(rhos)[1]-1) + " steps")
rho_bar = np.average(rhos, axis=0)
plt.plot(rho_bar)

plt.ylim([197,202])
plt.show()
# Out:
# 2000 runs, each of 1000 steps

# %%
rhos = pd.read_csv('autoc/total_s10by10.dat', header=None, skiprows=1).to_numpy()
# rhos = [rhos[5]]
print(str(np.shape(rhos)[0]) + " runs, each of " + str(np.shape(rhos)[1]-1) + " steps")

interval = np.shape(rhos)[1] - 1
cutoff=150

result = np.zeros((interval-cutoff)+1)
for rho in rhos:
    data = rho[cutoff:]
    x = data - np.mean(data)
    result += np.correlate(x, x, mode='full')[interval-cutoff:]/np.arange(1+interval-cutoff,0,-1)
result = result/len(rhos)

plt.plot(result)
# plt.ylim(-100,100)
# plt.savefig("img")
# Out:
# 100 runs, each of 500 steps

# %%
rhos = pd.read_csv('autoc/total_s10by10.dat', header=None, skiprows=1).to_numpy()
# rhos = [rhos[5]]
print(str(np.shape(rhos)[0]) + " runs, each of " + str(np.shape(rhos)[1]-1) + " steps")

interval = np.shape(rhos)[1] - 1
cutoff=250

result = np.zeros((interval-cutoff)+1)
for rho in rhos:
    data = rho[cutoff:]
    x = data - np.mean(data)
    result += np.correlate(x, x, mode='full')[interval-cutoff:]/np.arange(1+interval-cutoff,0,-1)
result = result/len(rhos)
plt.plot(result)

# plt.ylim(-100,100)
# plt.savefig("img")
plt.show()
# Out:
# 100 runs, each of 500 steps

# %%
cutoff=250
data = rhos[:,cutoff:]
interval = np.shape(data)[1]

result = np.zeros(interval)
for rho in data[50:]:
    partial_result = []
    x = rho - np.mean(rho)
    for t in range(interval):
        val = sum(x[t:] * x[:interval-t])/(interval-t)
        partial_result.append(val)
    result += partial_result
result /= np.shape(data)[0]
plt.plot(result)

result = np.zeros(interval)
for rho in data[:50]:
    partial_result = []
    x = rho - np.mean(rho)
    for t in range(interval):
        val = sum(x[t:] * x[:interval-t])/(interval-t)
        partial_result.append(val)
    result += partial_result
result /= np.shape(data)[0]
plt.plot(result)

# %%
plt.plot(data[0,0:10])

# %%
# Flippability Stuff

# %%
rhos = pd.read_csv('therm/flippable10by10.dat', header=None, skiprows=1).to_numpy()
print(str(np.shape(rhos)[0]) + " runs, each of " + str(np.shape(rhos)[1]-1) + " steps")
rho_bar = np.average(rhos, axis=0)
plt.plot(rho_bar)

plt.ylim(40,45)
plt.show()
# Out:
# 2000 runs, each of 40 steps

# %%
rhos = pd.read_csv('autoc/flippable10by10.dat', header=None, skiprows=1).to_numpy()
# rhos = [rhos[5]]
print(str(np.shape(rhos)[0]) + " runs, each of " + str(np.shape(rhos)[1]-1) + " steps")

interval = np.shape(rhos)[1] - 1
cutoff=15

result = np.zeros((interval-cutoff)+1)
for rho in rhos:
    data = rho[cutoff:]
    x = data - np.mean(data)
    result += np.correlate(x, x, mode='full')[interval-cutoff:]/np.arange(1+interval-cutoff,0,-1)
result = result/len(rhos)

plt.plot(result)
# plt.ylim(-2.5,2.5)
plt.savefig("flip_autoc")
plt.show()
# Out:
# 100 runs, each of 500 steps

# %%
# Label length stuff

# %%
for L in (4,6):
    rhos = pd.read_csv('therm/N_trivial' + str(L) + 'by' + str(L) + '.dat', header=None, skiprows=1).to_numpy()
    print(str(L) + ": " + str(np.shape(rhos)[0]) + " runs, each of " + str(np.shape(rhos)[1]-1) + " steps")
    rho_bar = np.average(rhos, axis=0)[1:]
    plt.plot(rho_bar / np.arange(1,np.shape(rhos)[1]))

plt.ylim(0.03,0.05)
plt.show()
# Out:
# 100 runs, each of 5000 steps

# %%
rho_bar
# Out:
# array([0.  , 0.55, 0.82, 0.96, 1.07, 1.19, 1.24, 1.3 , 1.38, 1.42, 1.44,
#        1.46, 1.47, 1.48, 1.49, 1.52, 1.54, 1.55, 1.58, 1.6 , 1.65, 1.69,
#        1.77, 1.8 , 1.83, 1.88, 1.95, 1.99, 2.02, 2.02, 2.04, 2.07, 2.09,
#        2.12, 2.15, 2.16, 2.16, 2.2 , 2.21, 2.24, 2.26, 2.27, 2.34, 2.36,
#        2.4 , 2.42, 2.44, 2.48, 2.56, 2.61, 2.64, 2.71, 2.74, 2.79, 2.82,
#        2.88, 2.91, 2.96, 2.97, 2.99, 3.02, 3.06, 3.1 , 3.14, 3.21, 3.23,
#        3.26, 3.27, 3.27, 3.3 , 3.32, 3.36, 3.37, 3.4 , 3.45, 3.49, 3.53,
#        3.57, 3.64, 3.66, 3.66, 3.69, 3.7 , 3.72, 3.74, 3.77, 3.78, 3.85,
#        3.88, 3.93, 3.97, 4.  , 4.04, 4.08, 4.09, 4.1 , 4.14, 4.18, 4.22,
#        4.27, 4.3 , 4.35, 4.39, 4.42, 4.44, 4.47, 4.51, 4.53, 4.62, 4.67,
#        4.73, 4.79, 4.8 , 4.88, 4.92, 4.96, 5.01, 5.06, 5.12, 5.14, 5.17,
#        5.19, 5.22, 5.3 , 5.34, 5.39, 5.46, 5.5 , 5.52, 5.59, 5.64, 5.65,
#        5.66, 5.71, 5.74, 5.79, 5.83, 5.87, 5.9 , 5.95, 5.99, 6.03, 6.08,
#        6.11, 6.15, 6.18, 6.23, 6.25, 6.3 , 6.31, 6.37, 6.39, 6.45, 6.48,
#        6.52, 6.55, 6.58, 6.61, 6.66, 6.69, 6.7 , 6.72, 6.77, 6.79, 6.83,
#        6.85, 6.86, 6.88, 6.9 , 6.96, 6.99, 7.03, 7.08, 7.13, 7.16, 7.22,
#        7.27, 7.33, 7.35, 7.39, 7.46, 7.5 , 7.53, 7.54, 7.59, 7.62, 7.62,
#        7.66, 7.69, 7.73, 7.78, 7.81, 7.84, 7.87, 7.91, 7.93, 7.97, 8.03,
#        8.09, 8.13, 8.17])
